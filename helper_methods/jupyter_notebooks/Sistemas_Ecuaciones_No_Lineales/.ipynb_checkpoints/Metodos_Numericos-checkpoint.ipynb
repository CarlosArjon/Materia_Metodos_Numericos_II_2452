# %%
from typing import Dict
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

from tools.newton.newton import Newton
from tools.fixed_point.fixed_point import FixedPoint
from tools.lagrange_polynomials.lagrange_polynomials import LagrangePolynomials

# %% [markdown]
# # Metodo de punto fijo

# %%
parameters = {}
parameters["vector_iterator"] = [-3.18, 0.4]
parameters["vector_aux"] = [0.0, 0.0]
parameters["table_output"] = {"x0": [], "x1": []}

# %%
fixed_point = FixedPoint(parameters)

# %%
fixed_point.logic_numeric_method()
# Out:
# ===================Iteración 0===================
#
# x_0 :  -3.1466252583997982
#
#
# x_1 :  0.04158565512117316
#
# ===================Iteración 1===================
#
# x_0 :  -3.1870116288234867
#
#
# x_1 :  0.0429969860158514
#
# ===================Iteración 2===================
#
# x_0 :  -3.1868771015839847
#
#
# x_1 :  0.04129509179459111
#
# ===================Iteración 3===================
#
# x_0 :  -3.1870393015126406
#
#
# x_1 :  0.041300647482982546
#
# ===================Iteración 4===================
#
# x_0 :  -3.1870387724753084
#
#
# x_1 :  0.04129394906416358
#
# ===================Iteración 5===================
#
# x_0 :  -3.187039410328143
#
#
# x_1 :  0.041293970910210004
#
#
#          x0        x1         error
# 0 -3.146625  0.041586  3.599649e-01
# 1 -3.187012  0.042997  4.041102e-02
# 2 -3.186877  0.041295  1.707203e-03
# 3 -3.187039  0.041301  1.622950e-04
# 4 -3.187039  0.041294  6.719278e-06
# 5 -3.187039  0.041294  6.382268e-07

# %% [markdown]
# # Metodo de Newton

# %%
parameters = {}
parameters["vector_iterator"] = [0.0, 0.0]
parameters["table_output"] = {"x0": [], "x1": []}

# %%
newton = Newton(parameters)

# %%
newton.logic_numeric_method()
# Out:
# ===================Iteración 0===================
#
# Jacobiana :  [[10.  2.]
#  [-1.  1.]]
#
#
# Determinante jacobiana :  12.0
#
#
# Funcion :  [[19.]
#  [ 1.]]
#
#
# x_k :  [0.0, 0.0]
#
#
# y :  [[1.41666667]
#  [2.41666667]]
#
#
# x_k+1 : x_k + y  [[1.41666667]
#  [2.41666667]]
#
# ===================Iteración 1===================
#
# Jacobiana :  [[58.40277778 23.34722222]
#  [-4.123353    1.        ]]
#
#
# Determinante jacobiana :  154.67161650570222
#
#
# Funcion :  [[-15.875     ]
#  [  1.70668633]]
#
#
# x_k :  [1.4166666666666665, 2.416666666666667]
#
#
# y :  [[-0.36025605]
#  [ 0.22122348]]
#
#
# x_k+1 : x_k + y  [[1.05641062]
#  [2.63789015]]
#
# ===================Iteración 2===================
#
# Jacobiana :  [[42.2882464  26.46848948]
#  [-2.87602928  1.        ]]
#
#
# Determinante jacobiana :  118.41239711989948
#
#
# Funcion :  [[-9.37836794]
#  [ 0.23813913]]
#
#
# x_k :  [1.0564106204504136, 2.637890149319459]
#
#
# y :  [[-0.13243167]
#  [-0.14273822]]
#
#
# x_k+1 : x_k + y  [[0.92397895]
#  [2.49515193]]
#
# ===================Iteración 3===================
#
# Jacobiana :  [[37.01695018 24.43217404]
#  [-2.51929463  1.        ]]
#
#
# Determinante jacobiana :  98.56879511399168
#
#
# Funcion :  [[-5.72456211]
#  [ 0.0241427 ]]
#
#
# x_k :  [0.9239789546662629, 2.4951519311983033]
#
#
# y :  [[-0.06406105]
#  [-0.13724597]]
#
#
# x_k+1 : x_k + y  [[0.8599179 ]
#  [2.35790597]]
#
# ===================Iteración 4===================
#
# Jacobiana :  [[34.59294601 22.55106495]
#  [-2.36296669  1.        ]]
#
#
# Determinante jacobiana :  87.88036132999142
#
#
# Funcion :  [[-3.57200548]
#  [ 0.00506072]]
#
#
# x_k :  [0.8599179017863854, 2.3579059659748154]
#
#
# y :  [[-0.04194487]
#  [-0.0940536 ]]
#
#
# x_k+1 : x_k + y  [[0.81797303]
#  [2.26385236]]
#
# ===================Iteración 5===================
#
# Jacobiana :  [[33.05025949 21.3054645 ]
#  [-2.26590227  1.        ]]
#
#
# Determinante jacobiana :  81.3263598763358
#
#
# Funcion :  [[-2.17786199e+00]
#  [ 2.04990778e-03]]
#
#
# x_k :  [0.8179730331872133, 2.263852363065159]
#
#
# y :  [[-0.02731631]
#  [-0.05984619]]
#
#
# x_k+1 : x_k + y  [[0.79065672]
#  [2.20400618]]
#
# ===================Iteración 6===================
#
# Jacobiana :  [[32.06451493 20.53131117]
#  [-2.20484392  1.        ]]
#
#
# Determinante jacobiana :  77.33285148494208
#
#
# Funcion :  [[-1.29791305e+00]
#  [ 8.37741176e-04]]
#
#
# x_k :  [0.7906567210386563, 2.20400617711644]
#
#
# y :  [[-0.01700588]
#  [-0.03665756]]
#
#
# x_k+1 : x_k + y  [[0.77365084]
#  [2.16734861]]
#
# ===================Iteración 7===================
#
# Jacobiana :  [[31.45837316 20.06419448]
#  [-2.16766563  1.        ]]
#
#
# Determinante jacobiana :  74.9508380106541
#
#
# Funcion :  [[-7.61283820e-01]
#  [ 3.17020658e-04]]
#
#
# x_k :  [0.773650843904683, 2.1673486135186977]
#
#
# y :  [[-0.01024197]
#  [-0.02188416]]
#
#
# x_k+1 : x_k + y  [[0.76340887]
#  [2.14546446]]
#
# ===================Iteración 8===================
#
# Jacobiana :  [[31.0961084  19.78789331]
#  [-2.14557776  1.        ]]
#
#
# Determinante jacobiana :  73.55257225054929
#
#
# Funcion :  [[-4.42000855e-01]
#  [ 1.13304792e-04]]
#
#
# x_k :  [0.763408869238573, 2.145464457666618]
#
#
# y :  [[-0.0060398 ]
#  [-0.01284556]]
#
#
# x_k+1 : x_k + y  [[0.75736907]
#  [2.1326189 ]]
#
# ===================Iteración 9===================
#
# Jacobiana :  [[30.88346041 19.62660234]
#  [-2.13265796  1.        ]]
#
#
# Determinante jacobiana :  72.7402900110815
#
#
# Funcion :  [[-2.55031373e-01]
#  [ 3.90558100e-05]]
#
#
# x_k :  [0.7573690679843685, 2.1326188991980826]
#
#
# y :  [[-0.00351659]
#  [-0.00746063]]
#
#
# x_k+1 : x_k + y  [[0.75385248]
#  [2.12515827]]
#
# ===================Iteración 10===================
#
# Jacobiana :  [[30.75998508 19.53322839]
#  [-2.12517144  1.        ]]
#
#
# Determinante jacobiana :  72.271444174859
#
#
# Funcion :  [[-1.46606739e-01]
#  [ 1.31712258e-05]]
#
#
# x_k :  [0.7538524762033064, 2.125158267571636]
#
#
# y :  [[-0.00203212]
#  [-0.00430543]]
#
#
# x_k+1 : x_k + y  [[0.75182036]
#  [2.12085284]]
#
# ===================Iteración 11===================
#
# Jacobiana :  [[30.68874572 19.47944493]
#  [-2.12085723  1.        ]]
#
#
# Determinante jacobiana :  72.0018672690394
#
#
# Funcion :  [[-8.40953211e-02]
#  [ 4.38497554e-06]]
#
#
# x_k :  [0.7518203594103975, 2.120852842228847]
#
#
# y :  [[-0.00116915]
#  [-0.00247521]]
#
#
# x_k+1 : x_k + y  [[0.75065121]
#  [2.11837763]]
#
# ===================Iteración 12===================
#
# Jacobiana :  [[30.64779669 19.44855814]
#  [-2.11837908  1.        ]]
#
#
# Determinante jacobiana :  71.84721544802612
#
#
# Funcion :  [[-4.81774141e-02]
#  [ 1.44893913e-06]]
#
#
# x_k :  [0.750651212815258, 2.118377634198424]
#
#
# y :  [[-0.00067095]
#  [-0.00141987]]
#
#
# x_k+1 : x_k + y  [[0.74998027]
#  [2.11695777]]
#
# ===================Iteración 13===================
#
# Jacobiana :  [[30.62430935 19.43085142]
#  [-2.11695824  1.        ]]
#
#
# Determinante jacobiana :  71.75861041639193
#
#
# Funcion :  [[-2.75803844e-02]
#  [ 4.76707027e-07]]
#
#
# x_k :  [0.7499802669253866, 2.1169577653985345]
#
#
# y :  [[-0.00038448]
#  [-0.00081345]]
#
#
# x_k+1 : x_k + y  [[0.74959579]
#  [2.11614432]]
#
# ===================Iteración 14===================
#
# Jacobiana :  [[30.61085423 19.42071081]
#  [-2.11614447  1.        ]]
#
#
# Determinante jacobiana :  71.70788407718678
#
#
# Funcion :  [[-1.57825180e-02]
#  [ 1.56448316e-07]]
#
#
# x_k :  [0.749595788364796, 2.1161443170478065]
#
#
# y :  [[-0.00022014]
#  [-0.00046569]]
#
#
# x_k+1 : x_k + y  [[0.74937565]
#  [2.11567863]]
#
# ===================Iteración 15===================
#
# Jacobiana :  [[30.6031517  19.41490667]
#  [-2.11567868  1.        ]]
#
#
# Determinante jacobiana :  71.67885588237321
#
#
# Funcion :  [[-9.02918552e-03]
#  [ 5.12707206e-08]]
#
#
# x_k :  [0.7493756513947941, 2.115678631863641]
#
#
# y :  [[-0.00012598]
#  [-0.00026648]]
#
#
# x_k+1 : x_k + y  [[0.74924967]
#  [2.11541215]]
#
# ===================Iteración 16===================
#
# Jacobiana :  [[30.59874409 19.4115857 ]
#  [-2.11541216  1.        ]]
#
#
# Determinante jacobiana :  71.66224860826404
#
#
# Funcion :  [[-5.16489466e-03]
#  [ 1.67885137e-08]]
#
#
# x_k :  [0.7492496702972782, 2.115412147611869]
#
#
# y :  [[-7.20772883e-05]
#  [-1.52456384e-04]]
#
#
# x_k+1 : x_k + y  [[0.74917759]
#  [2.11525969]]
#
# ===================Iteración 17===================
#
# Jacobiana :  [[30.59622252 19.40968589]
#  [-2.1152597   1.        ]]
#
#
# Determinante jacobiana :  71.65274880288766
#
#
# Funcion :  [[-2.95420321e-03]
#  [ 5.49479484e-09]]
#
#
# x_k :  [0.7491775930089533, 2.115259691227883]
#
#
# y :  [[-4.12309355e-05]
#  [-8.72086413e-05]]
#
#
# x_k+1 : x_k + y  [[0.74913636]
#  [2.11517248]]
#
# ===================Iteración 18===================
#
# Jacobiana :  [[30.59478013 19.40859919]
#  [-2.11517248  1.        ]]
#
#
# Determinante jacobiana :  71.6473151037596
#
#
# Funcion :  [[-1.68966190e-03]
#  [ 1.79793513e-09]]
#
#
# x_k :  [0.7491363620734508, 2.1151724825865514]
#
#
# y :  [[-2.35835327e-05]
#  [-4.98814415e-05]]
#
#
# x_k+1 : x_k + y  [[0.74911278]
#  [2.1151226 ]]
#
# ===================Iteración 19===================
#
# Jacobiana :  [[30.59395512 19.40797764]
#  [-2.1151226   1.        ]]
#
#
# Determinante jacobiana :  71.64420728154106
#
#
# Funcion :  [[-9.66380438e-04]
#  [ 5.88206817e-10]]
#
#
# x_k :  [0.7491127785407651, 2.1151226011450652]
#
#
# y :  [[-1.34887647e-05]
#  [-2.85298029e-05]]
#
#
# x_k+1 : x_k + y  [[0.74909929]
#  [2.11509407]]
#
# ===================Iteración 20===================
#
# Jacobiana :  [[30.59348325 19.40762215]
#  [-2.11509407  1.        ]]
#
#
# Determinante jacobiana :  71.64242979985707
#
#
# Funcion :  [[-5.52700787e-04]
#  [ 1.92418970e-10]]
#
#
# x_k :  [0.7490992897760715, 2.1150940713421993]
#
#
# y :  [[-7.71476516e-06]
#  [-1.63172616e-05]]
#
#
# x_k+1 : x_k + y  [[0.74909158]
#  [2.11507775]]
#
# ===================Iteración 21===================
#
# Jacobiana :  [[30.59321338 19.40741883]
#  [-2.11507775  1.        ]]
#
#
# Determinante jacobiana :  71.64141320605299
#
#
# Funcion :  [[-3.16102838e-04]
#  [ 6.29425401e-11]]
#
#
# x_k :  [0.7490915750109101, 2.115077754080562]
#
#
# y :  [[-4.41230911e-06]
#  [-9.33231389e-06]]
#
#
# x_k+1 : x_k + y  [[0.74908716]
#  [2.11506842]]
#
# ===================Iteración 22===================
#
# Jacobiana :  [[30.59305903 19.40730254]
#  [-2.11506842  1.        ]]
#
#
# Determinante jacobiana :  71.64083179138618
#
#
# Funcion :  [[-1.80785929e-04]
#  [ 2.05888639e-11]]
#
#
# x_k :  [0.7490871627018038, 2.115068421766669]
#
#
# y :  [[-2.52350963e-06]
#  [-5.33737493e-06]]
#
#
# x_k+1 : x_k + y  [[0.74908464]
#  [2.11506308]]
#
# ===================Iteración 23===================
#
# Jacobiana :  [[30.59297075 19.40723604]
#  [-2.11506308  1.        ]]
#
#
# Determinante jacobiana :  71.6404992678926
#
#
# Funcion :  [[-1.03395030e-04]
#  [ 6.73461287e-12]]
#
#
# x_k :  [0.749084639192177, 2.115063084391734]
#
#
# y :  [[-1.44325015e-06]
#  [-3.05255837e-06]]
#
#
# x_k+1 : x_k + y  [[0.7490832 ]
#  [2.11506003]]
#
# ===================Iteración 24===================
#
# Jacobiana :  [[30.59292026 19.407198  ]
#  [-2.11506003  1.        ]]
#
#
# Determinante jacobiana :  71.64030909113292
#
#
# Funcion :  [[-5.91335596e-05]
#  [ 2.20312657e-12]]
#
#
# x_k :  [0.7490831959420317, 2.1150600318333646]
#
#
# y :  [[-8.25423608e-07]
#  [-1.74581828e-06]]
#
#
# x_k+1 : x_k + y  [[0.74908237]
#  [2.11505829]]
#
# ===================Iteración 25===================
#
# Jacobiana :  [[30.59289139 19.40717625]
#  [-2.11505829  1.        ]]
#
#
# Determinante jacobiana :  71.64020032546252
#
#
# Funcion :  [[-3.38195630e-05]
#  [ 7.20756788e-13]]
#
#
# x_k :  [0.7490823705184239, 2.1150582860150853]
#
#
# y :  [[-4.72075410e-07]
#  [-9.98466288e-07]]
#
#
# x_k+1 : x_k + y  [[0.7490819 ]
#  [2.11505729]]
#
# ===================Iteración 26===================
#
# Jacobiana :  [[30.59287487 19.40716381]
#  [-2.11505729  1.        ]]
#
#
# Determinante jacobiana :  71.64013812038549
#
#
# Funcion :  [[-1.9342016e-05]
#  [ 2.3581137e-13]]
#
#
# x_k :  [0.7490818984430134, 2.1150572875487974]
#
#
# y :  [[-2.69988599e-07]
#  [-5.71041118e-07]]
#
#
# x_k+1 : x_k + y  [[0.74908163]
#  [2.11505672]]
#
#
#           x0        x1         error
# 0   1.416667  2.416667  2.801289e+00
# 1   1.056411  2.637890  4.227579e-01
# 2   0.923979  2.495152  1.947109e-01
# 3   0.859918  2.357906  1.514605e-01
# 4   0.817973  2.263852  1.029828e-01
# 5   0.790657  2.204006  6.578561e-02
# 6   0.773651  2.167349  4.041011e-02
# 7   0.763409  2.145464  2.416225e-02
# 8   0.757369  2.132619  1.419463e-02
# 9   0.753852  2.125158  8.247875e-03
# 10  0.751820  2.120853  4.760902e-03
# 11  0.750651  2.118378  2.737436e-03
# 12  0.749980  2.116958  1.570413e-03
# 13  0.749596  2.116144  8.997344e-04
# 14  0.749376  2.115679  5.150951e-04
# 15  0.749250  2.115412  2.947628e-04
# 16  0.749178  2.115260  1.686360e-04
# 17  0.749136  2.115172  9.646418e-05
# 18  0.749113  2.115123  5.517555e-05
# 19  0.749099  2.115094  3.155783e-05
# 20  0.749092  2.115078  1.804912e-05
# 21  0.749087  2.115068  1.032282e-05
# 22  0.749085  2.115063  5.903869e-06
# 23  0.749083  2.115060  3.376549e-06
# 24  0.749082  2.115058  1.931115e-06
# 25  0.749082  2.115057  1.104441e-06
# 26  0.749082  2.115057  6.316501e-07
