# %%
from typing import Dict
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

from tools.newton.newton import Newton
from tools.fixed_point.fixed_point import FixedPoint
from tools.lagrange_polynomials.lagrange_polynomials import LagrangePolynomials

# %% [markdown]
# # Metodo de punto fijo

# %%
parameters = {}
parameters["vector_iterator"] = [-3.16, 0.04]
parameters["vector_aux"] = [0.0, 0.0]
parameters["table_output"] = {"x0": [], "x1": []}

# %%
fixed_point = FixedPoint(parameters)

# %%
fixed_point.logic_numeric_method()
# Out:
# ===================Iteración 0===================
#
# x_0 :  -3.187162545399861
#
#
# x_1 :  0.042425741080511385
#
# ===================Iteración 1===================
#
# x_0 :  -3.1869315752593974
#
#
# x_1 :  0.04128886015095739
#
# ===================Iteración 2===================
#
# x_0 :  -3.1870398949139234
#
#
# x_1 :  0.041298397746193496
#
# ===================Iteración 3===================
#
# x_0 :  -3.1870389867055966
#
#
# x_1 :  0.041293924560288506
#
# ===================Iteración 4===================
#
# x_0 :  -3.187039412661502
#
#
# x_1 :  0.04129396206379166
#
#
#          x0        x1         error
# 0 -3.187163  0.042426  2.727065e-02
# 1 -3.186932  0.041289  1.160106e-03
# 2 -3.187040  0.041298  1.087387e-04
# 3 -3.187039  0.041294  4.564453e-06
# 4 -3.187039  0.041294  4.276037e-07

# %% [markdown]
# # Metodo de Newton

# %%
parameters = {}
parameters["vector_iterator"] = [-3.18 , 0.045]
parameters["table_output"] = {"x0": [], "x1": []}

# %%
newton = Newton(parameters)

# %%
newton.logic_numeric_method()
# Out:
# ===================Iteración 0===================
#
# Jacobiana :  [[ 4.75240000e+01  2.18405000e+00]
#  [-4.15856551e-02  1.00000000e+00]]
#
#
# Determinante jacobiana :  47.614825150067404
#
#
# Funcion :  [[ 0.145975  ]
#  [-0.00341434]]
#
#
# x_k :  [-3.18, 0.045]
#
#
# y :  [[ 0.00322236]
#  [-0.00328034]]
#
#
# x_k+1 : x_k + y  [[-3.17677764]
#  [ 0.04171966]]
#
# ===================Iteración 1===================
#
# Jacobiana :  [[ 4.73836089e+01  2.17035970e+00]
#  [-4.17198752e-02  1.00000000e+00]]
#
#
# Determinante jacobiana :  47.47415608305739
#
#
# Funcion :  [[2.23015678e-01]
#  [2.16136558e-07]]
#
#
# x_k :  [-3.1767776401688126, 0.04171965906578925]
#
#
# y :  [[0.00469761]
#  [0.0001962 ]]
#
#
# x_k+1 : x_k + y  [[-3.17208003]
#  [ 0.04191586]]
#
# ===================Iteración 2===================
#
# Jacobiana :  [[ 4.71793164e+01  2.17117731e+00]
#  [-4.19163201e-02  1.00000000e+00]]
#
#
# Determinante jacobiana :  47.27032421086102
#
#
# ...
